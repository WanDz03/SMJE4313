# %% [markdown]
# <a href="https://colab.research.google.com/github/WanDz03/SMJE4313/blob/main/Wan_canny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **In this code we are going to explore about Canny edge detector. The Canny edge detector is a multi-step process.**
#
# First we need to mount our code with google drive.

# %%
# To mount code with google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import all the package that we will use for the code.

# %%
# Import the necessary packages
import numpy as np
import argparse
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# Set the path for the image that we will use for testing the code.
#
# When you mount the code, folder **"drive"** will appear on the left screen when you click the **"file"** symbol. Then you just need to find the image in your drive and right click on that image.
#
# A pop up will show some list then just click **"copy path"**. After that you just need to paste the path here.

# %%
# Construct the argument parser and parse the arguments
args = {
	# Task 1
	"image": "/content/drive/MyDrive/Colab Notebooks/SMJE4313 Image Processing/image/mjiit.jpg"
}
print(args)
# Out:
# {'image': '/content/drive/MyDrive/Colab Notebooks/SMJE4313 Image Processing/image/mjiit.jpg'}

# %% [markdown]
# Now that we have the path to the image, we can load it off the disk using the cv2.imread function on Line 2. The cv2.imread function returns a NumPy array representing the image.
#
# On line 3, we convert the image into grayscale and apply gaussian blur on line 4.
#
# Then, displaying the actual image on our screen. The parameter is a reference to the image we convert before.

# %%
# Task 2
# Load the image :
image =  cv2.imread(args["image"])
cv2_imshow(image)

# Task 3
# Convert image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)

# Task 4
# Apply gaussian blur with size 5x5
blurred = cv2.GaussianBlur(gray, (5, 5), 0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=RGB size=800x273 at 0x7FAC8F45A440>
# <PIL.Image.Image image mode=L size=800x273 at 0x7FAC8F45A440>
# <PIL.Image.Image image mode=L size=800x273 at 0x7FAC5C7CF490>

# %% [markdown]
# When performing Canny edge detection we need two values for hysteresis: threshold1 and threshold2. Any gradient value larger than threshold2 are considered to be an edge. Any value below threshold1 are considered not to be an edge. Values in between threshold1 and threshold2 are either classified as edges or non-edges based on how the intensities are "connected". In this case, any gradient values below 30 are considered non-edges whereas any value above 150 are considered edges.

# %%
canny = cv2.Canny(image, 30, 150)

#Task 5
# Show canny image here :
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=800x273 at 0x7FAC5C7CD840>
